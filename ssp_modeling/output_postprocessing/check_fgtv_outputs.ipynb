# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/tony/Documents/sisepuede_modeling/ssp_bulgaria/ssp_modeling/ssp_run_output/sisepuede_results_sisepuede_run_2025-11-25T13;06;32.189421/decomposed_ssp_output.csv")
df.head()
# Out:
#    primary_id    region  time_period  area_agrc_crops_bevs_and_spices  \
# 0           0  bulgaria            7                                0
# 1           0  bulgaria            8                                0
# 2           0  bulgaria            9                                0
# 3           0  bulgaria           10                                0
# 4           0  bulgaria           11                                0
#
#    area_agrc_crops_cereals  area_agrc_crops_fibers  area_agrc_crops_fruits  \
# 0             1.852232e+06             4451.131237            75770.808645
# 1             1.846531e+06             4437.432477            75537.617106
# 2             1.840893e+06             4423.882719            75306.962006
# 3             1.835316e+06             4410.480185            75078.813083
# 4             1.829799e+06             4397.223133            74853.140670
#
#    area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                     39938.287990           7487.286250
# 1                                     39815.374284           7464.243447
# 2                                     39693.797519           7441.451282
# 3                                     39573.541743           7418.906765
# 4                                     39454.591319           7396.606964
#
#    area_agrc_crops_other_annual  ...  \
# 0                  2.345258e+06  ...
# 1                  2.338040e+06  ...
# 2                  2.330901e+06  ...
# 3                  2.323839e+06  ...
# 4                  2.316854e+06  ...
#
#    yf_agrc_herbs_and_other_perennial_crops_tonne_ha  yf_agrc_nuts_tonne_ha  \
# 0                                          1.011737               0.509224
# 1                                          1.011737               0.380228
# 2                                          1.011737               0.380228
# 3                                          1.011737               0.380228
# 4                                          1.011737               0.380228
#
#    yf_agrc_other_annual_tonne_ha  yf_agrc_other_woody_perennial_tonne_ha  \
# 0                       2.194576                                     0.5
# 1                       3.079152                                     0.5
# 2                       3.079152                                     0.5
# 3                       3.079152                                     0.5
# 4                       3.079152                                     0.5
#
#    yf_agrc_pulses_tonne_ha  yf_agrc_rice_tonne_ha  \
# 0                 1.937249               6.079400
# 1                 1.578307               5.689031
# 2                 1.578307               5.689031
# 3                 1.578307               5.689031
# 4                 1.578307               5.689031
#
#    yf_agrc_sugar_cane_tonne_ha  yf_agrc_tubers_tonne_ha  \
# 0                    55.765409                18.800200
# 1                    55.765409                21.599397
# 2                    55.765409                21.599397
# 3                    55.765409                21.599397
# 4                    55.765409                21.599397
#
#    yf_agrc_vegetables_and_vines_tonne_ha  \
# 0                               2.759238
# 1                               2.875868
# 2                               2.875868
# 3                               2.875868
# 4                               2.875868
#
#    yf_lndu_supremum_pastures_tonne_per_ha
# 0                                   92.81
# 1                                   92.81
# 2                                   92.81
# 3                                   92.81
# 4                                   92.81
#
# [5 rows x 4054 columns]

# %%
df[df.primary_id==75075][[col for col in df.columns if 'fgtv' in col and "emission_co2e_subsector" in col]].plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
df[df.primary_id==75075][[col for col in df.columns if 'fgtv' in col and "emission_co2e_" in col and not "total" in col]].sum()
# Out:
# emission_co2e_ch4_fgtv_fuel_coal           13.173331
# emission_co2e_ch4_fgtv_fuel_natural_gas     3.647767
# emission_co2e_ch4_fgtv_fuel_oil             0.002379
# emission_co2e_co2_fgtv_fuel_coal            4.333035
# emission_co2e_co2_fgtv_fuel_natural_gas    12.595232
# emission_co2e_co2_fgtv_fuel_oil             0.000058
# emission_co2e_n2o_fgtv_fuel_coal            0.000000
# emission_co2e_n2o_fgtv_fuel_natural_gas     0.001202
# emission_co2e_n2o_fgtv_fuel_oil             0.000000
# dtype: float64

# %%
fields = [
    "emission_co2e_co2_fgtv_fuel_coal",
    "emission_co2e_co2_fgtv_fuel_natural_gas",
    "emission_co2e_co2_fgtv_fuel_oil",
    "emission_co2e_co2_entc_mining_and_extraction_me_coal",
    "emission_co2e_co2_entc_mining_and_extraction_me_crude",
    "emission_co2e_co2_entc_mining_and_extraction_me_natural_gas",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_ammonia_production",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_hydrogen_electrolysis",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_hydrogen_gasification",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_hydrogen_reformation",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_hydrogen_reformation_ccs",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_natural_gas",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_natural_gas_liquefaction",
    "emission_co2e_co2_entc_nbmass_processing_and_refinement_fp_petroleum_refinement",
]

df[df.primary_id==75075][fields].plot(figsize=(10,10))
# Out:
# <Axes: >
